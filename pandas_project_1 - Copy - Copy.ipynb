# %%
# import packages
import numpy as np
import pandas as pd

# %%
#take the csv file into the jupyter note book
importing_csvfile=pd.read_csv(r"C:\Users\ASUS\Desktop\faa_ai_prelim.csv")
print(importing_csvfile)
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME     LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z        MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z         TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z           TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z         ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z         TALKEETNA
# 5       No  19-FEB-16      18-FEB-16      20:23:00Z      PEARL HARBOR
# 6       No  18-FEB-16      17-FEB-16      21:15:00Z       BROOKSVILLE
# 7       No  18-FEB-16      17-FEB-16      18:10:00Z      WINTER HAVEN
# 8       No  18-FEB-16      17-FEB-16      13:50:00Z             MIAMI
# 9       No  18-FEB-16      17-FEB-16      15:30:00Z  FERNANDINA BEACH
# 10      No  18-FEB-16      17-FEB-16      15:40:00Z      NEWPORT NEWS
# 11      No  17-FEB-16      15-FEB-16      16:12:00Z           PHOENIX
# ...

# %%
#view the csv file into data frame
FAA=pd.DataFrame(importing_csvfile )

# %%
print(FAA)
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME     LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z        MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z         TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z           TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z         ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z         TALKEETNA
# 5       No  19-FEB-16      18-FEB-16      20:23:00Z      PEARL HARBOR
# 6       No  18-FEB-16      17-FEB-16      21:15:00Z       BROOKSVILLE
# 7       No  18-FEB-16      17-FEB-16      18:10:00Z      WINTER HAVEN
# 8       No  18-FEB-16      17-FEB-16      13:50:00Z             MIAMI
# 9       No  18-FEB-16      17-FEB-16      15:30:00Z  FERNANDINA BEACH
# 10      No  18-FEB-16      17-FEB-16      15:40:00Z      NEWPORT NEWS
# 11      No  17-FEB-16      15-FEB-16      16:12:00Z           PHOENIX
# ...

# %%
FAA.head()
# Out:
#   UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0      No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1      No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2      No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3      No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4      No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
#
#    LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0  North Carolina            NaN
# 1         Florida            NaN
# 2      New Jersey            NaN
# 3  North Carolina            NaN
# 4          Alaska            NaN
#
#                                             RMK_TEXT EVENT_TYPE_DESC  \
# 0  AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1  AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2  AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3  AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# ...

# %%
#to view aircraft make name
#state name
#aircraft model name
#text information
#flight phase
#event description type
#fatal flag

# %%
FAA.columns
# Out:
# Index(['UPDATED', 'ENTRY_DATE', 'EVENT_LCL_DATE', 'EVENT_LCL_TIME',
#        'LOC_CITY_NAME', 'LOC_STATE_NAME', 'LOC_CNTRY_NAME', 'RMK_TEXT',
#        'EVENT_TYPE_DESC', 'FSDO_DESC', 'REGIST_NBR', 'FLT_NBR', 'ACFT_OPRTR',
#        'ACFT_MAKE_NAME', 'ACFT_MODEL_NAME', 'ACFT_MISSING_FLAG',
#        'ACFT_DMG_DESC', 'FLT_ACTIVITY', 'FLT_PHASE', 'FAR_PART', 'MAX_INJ_LVL',
#        'FATAL_FLAG', 'FLT_CRW_INJ_NONE', 'FLT_CRW_INJ_MINOR',
#        'FLT_CRW_INJ_SERIOUS', 'FLT_CRW_INJ_FATAL', 'FLT_CRW_INJ_UNK',
#        'CBN_CRW_INJ_NONE', 'CBN_CRW_INJ_MINOR', 'CBN_CRW_INJ_SERIOUS',
#        'CBN_CRW_INJ_FATAL', 'CBN_CRW_INJ_UNK', 'PAX_INJ_NONE', 'PAX_INJ_MINOR',
#        'PAX_INJ_SERIOUS', 'PAX_INJ_FATAL', 'PAX_INJ_UNK', 'GRND_INJ_NONE',
#        'GRND_INJ_MINOR', 'GRND_INJ_SERIOUS', 'GRND_INJ_FATAL', 'GRND_INJ_UNK'],
#       dtype='object')

# %%
Required_name=FAA[['LOC_STATE_NAME','RMK_TEXT','ACFT_MODEL_NAME','FATAL_FLAG','EVENT_TYPE_DESC',]]

# %%
print(pd.DataFrame(Required_name))
# Out:
#     LOC_STATE_NAME                                           RMK_TEXT  \
# 0   North Carolina  AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...
# 1          Florida  AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...
# 2       New Jersey  AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...
# 3   North Carolina  AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...
# 4           Alaska  AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...
# 5           Hawaii  N80918 BELL 206B ROTORCRAFT CRASHED INTO THE W...
# 6          Florida  AIRCRAFT GEAR COLLAPSED ON LANDING, BROOKSVILL...
# 7          Florida  AIRCRAFT ON LANDING GEAR COLLAPSED, WINTER HAV...
# 8          Florida  N859GT ATLAS AIR FLIGHT GTI33 BOEING 747 AIRCR...
# 9          Florida  AIRCRAFT, LSA PARADISE P1,  ON LANDING NOSE GE...
# 10        Virginia  AIRCRAFT ON LANDING WENT OFF THE RUNWAY INTO A...
# 11         Arizona  N2194X FIREFLY 9 BALLOON, ON LANDING STRUCK TH...
# ...

# %%
Required_name.columns
# Out:
# Index(['LOC_STATE_NAME', 'RMK_TEXT', 'ACFT_MODEL_NAME', 'FATAL_FLAG',
#        'EVENT_TYPE_DESC'],
#       dtype='object')

# %%
#replace the NAN as No
fatalflag=Required_name.FATAL_FLAG
After_FIlling=fatalflag.fillna("NO")

# %%
print(After_FIlling)
# Out:
# 0     Yes
# 1      NO
# 2      NO
# 3      NO
# 4      NO
# 5      NO
# 6      NO
# 7      NO
# 8      NO
# 9      NO
# 10     NO
# 11     NO
# 12     NO
# 13     NO
# 14     NO
# 15     NO
# 16     NO
# 17     NO
# 18     NO
# 19     NO
# 20     NO
# 21     NO
# 22    Yes
# 23     NO
# 24     NO
# 25     NO
# 26     NO
# 27     NO
# 28     NO
# 29     NO
#      ...
# 53    Yes
# 54     NO
# 55    Yes
# 56     NO
# 57     NO
# 58     NO
# 59     NO
# 60     NO
# 61     NO
# 62     NO
# 63     NO
# 64     NO
# 65     NO
# 66     NO
# 67     NO
# 68     NO
# 69     NO
# 70     NO
# 71     NO
# 72     NO
# 73     NO
# 74     NO
# 75     NO
# 76     NO
# 77     NO
# 78     NO
# 79    Yes
# 80    Yes
# 81    Yes
# 82    Yes
# Name: FATAL_FLAG, Length: 83, dtype: object

# %%
#to find the aircrafts types and the occuriences in it
with_out_na=FAA.ACFT_MODEL_NAME.dropna()

# %%
#print it
print(with_out_na)
#now find occurience of each type
with_out_na.groupby(with_out_na)
with_out_na.size
# Out:
# 0           36
# 1          RV7
# 2          172
# 3          235
# 4          172
# 5          206
# 6         PA24
# 7          210
# 8          747
# 10         172
# 11     FIREFLY
# 12         310
# 13         210
# 14         T34
# 15         152
# 16    EAGLE II
# 17        PA34
# 18        PA28
# 19         150
# 20         369
# 21         210
# 23         737
# 24        GC1B
# 25        PA20
# 26        2T1A
# 27         560
# 28        BT15
# 29         210
# 30          36
# 31         172
#         ...
# 52         182
# 53        PA28
# 54         150
# 55        CTLS
# 56        PA34
# 57      KITFOX
# 59        PA28
# 60        PA34
# 61          36
# 62          33
# 63         206
# 64         206
# 65         175
# 66        PA31
# 67          IV
# 68          35
# 69        M20K
# 70         500
# 71         310
# 72        M20E
# 73          35
# 74       NA265
# 75        M20K
# 76        PA24
# 77         737
# 78        O58B
# 79         F51
# 80       8KCAB
# ...

# %%
s=fatalflag.dropna()

# %%
print(s)
# Out:
# 0     Yes
# 22    Yes
# 53    Yes
# 55    Yes
# 79    Yes
# 80    Yes
# 81    Yes
# 82    Yes
# Name: FATAL_FLAG, dtype: object
