# %%
#import packages numpy and pandas
import numpy as np
import pandas as pd

# %%
#The total number of fire department facilities in New York city
#The number of fire department facilities in each borough
#The facility names in Manhattan

# %%
#import csv files into the jfile
importing_csvfile=pd.read_csv(r"C:\Users\ASUS\Desktop\FDNY.csv")

# %%
make_Dataframe=pd.DataFrame(importing_csvfile)

# %%
print(make_Dataframe)
count_of_fire_departments=make_Dataframe.count()
print(count_of_fire_departments)
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                             Ladder 8
# 6                                    Engine 9/Ladder 6
# 7                      Engine 15/Ladder 18/Battalion 4
# 8                                  Engine 28/Ladder 11
# 9                                             Engine 5
# 10                                           Engine 55
# 11                                Ladder 20/Division 1
# 12                      Engine 24/Ladder 5/Battalion 2
# 13                                  Engine 33/Ladder 9
# 14                                Ladder 3/Battalion 6
# 15                                            Squad 18
# ...

# %%
make_Dataframe.head()
# Out:
#                                         FacilityName       FacilityAddress  \
# 0                                       FacilityName       FacilityAddress
# 1                                 Engine 4/Ladder 15       42 South Street
# 2                                Engine 10/Ladder 10    124 Liberty Street
# 3                                           Engine 6     49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  100-104 Duane Street
#
#      Borough
# 0    Borough
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
#to find the facility name of borough present in manhattan
facility_names_in_manhattan=make_Dataframe.groupby("Borough")
x=facility_names_in_manhattan.get_group("Manhattan")
y=x.count
print(x.FacilityName)

#print(y)
# Out:
# 1                                    Engine 4/Ladder 15
# 2                                   Engine 10/Ladder 10
# 3                                              Engine 6
# 4     Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                              Ladder 8
# 6                                     Engine 9/Ladder 6
# 7                       Engine 15/Ladder 18/Battalion 4
# 8                                   Engine 28/Ladder 11
# 9                                              Engine 5
# 10                                            Engine 55
# 11                                 Ladder 20/Division 1
# 12                       Engine 24/Ladder 5/Battalion 2
# 13                                   Engine 33/Ladder 9
# 14                                 Ladder 3/Battalion 6
# 15                                             Squad 18
# 16                                  Engine 34/Ladder 21
# 17                                            Engine 26
# ...

# %%
#count the number of firedpts in each borough
facility_names_in_manhattan=make_Dataframe.groupby("Borough")
facility_names_in_manhattan.size() #dont forget the count using size
# Out:
# Borough
# Borough           1
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# dtype: int64
